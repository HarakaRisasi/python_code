# %% [markdown]
# ---
# > # **RGB image in python**
# ---
# ---
# ## **RGB**
# ![](../Week-3-2-numpy_satellite/Screenshot_1.png)
# ---
# ---
# ## **RGB in Python(ndarrays)**
# ![](../Week-3-2-numpy_satellite/Screenshot_10.png)
# ---

# %%
import numpy as np
import imageio as img # Library to get image

# %%
photo_data = img.imread('../Week-3-2-numpy_satellite/wifire/sd-3layers.jpg')

# %%
plt.figure(figsize=(20,20))
plt.imshow(photo_data)

# %%
print(type(photo_data))
print()
print(f'Size of image(px): {photo_data.shape}')
# Out:
# <class 'imageio.core.util.Array'>
#
# Size of image(px): (3725, 4797, 3)
