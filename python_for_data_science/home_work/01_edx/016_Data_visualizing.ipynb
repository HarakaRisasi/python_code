# %% [markdown]
# ### <font color = #2467C0>Data visualization</font>

# %%
import pandas as pd

# %%
movies = pd.read_csv('../Week-4-Pandas/movielens/movies.csv', sep = ',')
tags = pd.read_csv('../Week-4-Pandas/movielens/tags.csv', sep = ',')
ratings = pd.read_csv('../Week-4-Pandas/movielens/ratings.csv', sep = ',')

# %%
# %matplotlib inline

ratings.hist(column='rating', figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001608DEDB388>]],
#       dtype=object)

# %%
ratings.boxplot(column='rating', figsize=(15,20))

# %% [markdown]
# > Plotting
#
# https://pandas.pydata.org/pandas-docs/stable/reference/frame.html
