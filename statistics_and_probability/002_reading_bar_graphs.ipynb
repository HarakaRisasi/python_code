# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
student = ['Jasmine', 'Jeff', 'Nevin', 'Alejandra', 'Marta']

score_midterm = [73, 88, 83, 82, 96]
score_final_exam = [79, 85, 88, 95, 91]

# %%
df = pd.DataFrame({'Midterm Exam':score_midterm, 
                   'Final Exam':score_final_exam}, index=student)

df.plot.bar(rot = 0,  figsize=(10, 7))
