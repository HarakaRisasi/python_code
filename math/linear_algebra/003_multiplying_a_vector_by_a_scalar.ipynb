# %% [markdown]
# ---
# $
# \overrightarrow{a} =
# \begin{align}
#     \begin{bmatrix}
#     2 \\
#     1
#     \end{bmatrix}
# \end{align}
# $
#
# $
# 3\overrightarrow{a} = 3
# \begin{align}
#     \begin{bmatrix}
#     2 \\
#     1
#     \end{bmatrix} =
#     \begin{bmatrix}
#     3 * 2 \\
#     3 * 1
#     \end{bmatrix} =
#     \begin{bmatrix}
#     6 \\
#     3
#     \end{bmatrix}
# \end{align}
# $

# %% [markdown]
# ![multiplying_vectors.png](attachment:multiplying_vectors.png)

# %% [markdown]
# ---
# $
# -1\overrightarrow{a} =
# \begin{align}
#     \begin{bmatrix}
#     -2 \\
#     -1
#     \end{bmatrix}
# \end{align}
# $

# %% [markdown]
# $
# -2\overrightarrow{a} = -2
# \begin{align}
#     \begin{bmatrix}
#     2 \\
#     1
#     \end{bmatrix} =
#     \begin{bmatrix}
#     -2 * 2 \\
#     -2 * 1
#     \end{bmatrix} =
#     \begin{bmatrix}
#     -4 \\
#     -2
#     \end{bmatrix}
# \end{align}
# $

# %% [markdown]
# ![multiplying_vectors_negative.png](attachment:multiplying_vectors_negative.png)
