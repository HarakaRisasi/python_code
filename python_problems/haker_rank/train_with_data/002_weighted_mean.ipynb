# %% [markdown]
# ### Task
# Given an array, $X$, of $N$ integers and an array, $W$, representing the respective weights of $X$'s elements,\
# calculate and print the weighted mean of $X$'s elements.\
# Your answer should be rounded to a scale of $1$ decimal place (i.e., $12.3$ format).
#
# **Sample Input**:
# 5
# 10 40 30 50 20
# 1 2 3 4 5
#
# **Sample Output**:
# 32.0
#
# **Explanation**
#
# We use the following formula to calculate the weighted mean:\
# $$m_w = \frac{\sum_{i=0}^{N-1}(x_i * w_i)}{\sum_{i=0}^{N-1} w_i} \Rightarrow m_w = \frac{10 * 1 + 40 * 2 + 30 * 3 + 50 * 4 + 20 * 5}{1 + 2 + 3 + 4 + 5} = \frac{480}{15} = 32$$
#
# And then print our result to a scale of $1$ decimal place ($32.0$) on a new line.

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n = input()

x = list(map(int, input().split()))
w = list(map(int, input().split()))

m = round(sum([x * w for x, w in zip(x, w)]) / sum(w), 1)

print(m)

# %% [markdown]
# ## Давайте попробуем взвешенные средние в нескольких примерах:
#
# **Первый пример**
# Вы знаете, какой у вас рост?\
# Я имею в виду, большинство людей. Я сам большой $6'3 ″$ или $190,5$ см.
# Но это выше или ниже, чем в среднем для мужчины, женщины или человека в целом? Давайте взглянем.
#
# Средний рост мужчин в США составляет $177$ см. Я собираюсь использовать сантиметры в этом примере, потому что это непрерывная переменная , а в футах и дюймах - нет. Так что я немного выше среднего. Средний рост самок в США составляет $162$ см. Я все еще немного выше среднего.
#
# Оба они средние, но это не говорит нам о среднем росте среднего человека . Я имею в виду, что это средний рост человека, выбранного случайным образом из населения Соединенных Штатов. СЕЙЧАС нам нужно средневзвешенное значение, чтобы учесть тот факт, что население США не одинаково распределено между женщинами и мужчинами.
#
# Около $51,5%$ США идентифицируют себя как женщины, а остальные $48,5%$ идентифицируют себя как мужчины. Таким образом, наше среднее должно принимать во внимание это неравное взвешивание. Используя наши настройки из предыдущего примера, мы получаем формулу, которая выглядит следующим образом
#
#
# Теперь наш средний показатель объясняет тот факт, что население даже не взвешено. Это реальная цель взвешенных средних. Они учитывают неравные веса в выборке или популяции. В статистике вы увидите, что они чаще всего учитывают пол, расу, этническую принадлежность и другие номинальные вещи.
#
# **Второй пример**
# Средневзвешенное значение также используется в бизнесе для учета цен на товары и услуги, приобретенные у разных поставщиков.Это интересно.
#
# Допустим, вы запустили линию одежды. Но вам понадобится немного ткани.
#
# Таким образом, вы покупаете $1000$ ярдов красивой белой ткани у одного продавца по $\$1,50$ доллара за ярд. Поскольку вы купили все, что у них было, вам придется получать больше от второго поставщика в процессе производства. Фактически, вы покупаете $1700$ ярдов по $\$1,75$ доллара за ярд. Теперь вы можете работать по цене $\$1,63$ за ярд, но вы потеряете деньги, потому что купили больше по более высокой цене!\
# Итак, рассчитайте средневзвешенное значение, используя метраж в качестве веса.
#
# Это означает, что ваш инвентарь ткани в среднем стоит $\$1,66$ долл. США за ярд, что должно более точно учитывать ваши затраты.
#
# **Средневзвешенное значение** - это одна из тех вещей, которая используется для более точного изображения выборки по отношению к населению.\
# Есть некоторые особенности, когда вы хотите его использовать, такие как **выбросы** и **дисперсия**, но в целом это довольно хорошо продуманный способ учета различий в данных. Не говоря уже о всех местах, где он появляется в школах, социологических исследованиях и даже в бизнесе. Удачной статистики!
