# %%
import pandas as pd

pd.read_excel("../tips/docs/for_operators.xls")
# Out:
#    Операторы и их применение                     Название  \
# 0                          +                     Сложение
# 1                          -                    Вычитание
# 2                          *                    Умножение
# 3                         **         Возведение в степень
# 4                          /                      Деление
# 5                         //        Целочисленное деление
# 6                          %            Деление по модулю
# 7                         <<                  Сдвиг влево
# 8                         >>                 Сдвиг вправо
# 9                          &                  Побитовое И
# 10                         |                Побитовое ИЛИ
# 11                         ^  Побитовое ИСКЛЮЧИТЕЛЬНО ИЛИ
# 12                         ~                 Побитовое НЕ
# 13                         <                       Меньше
# 14                         >                       Больше
# ...

# %%
x = 1905

# operator output first two sign
print(x // 100)
# operator output last one sign
print(x % 100)

# addition first and last signs: 1905 => 19 + 05 = 24
print(x // 100 + x % 100)
# Out:
# 19
# 5
# 24
