# %% [markdown]
# ### Introduction
# Oftentimes data will come to us with column names, index names, or other naming convention that we are not satisfied with.
# In that case, you'll learn how to use pandas functions to change the names of the offending entries to something better.

# %%
import pandas as pd

# %%
wine_store = pd.read_csv('../data/wine_catalog/wine_store_dataset.csv')
wine_store = wine_store.drop(columns='Unnamed: 0')
wine_store.head(2)
# Out:
#   country                           designation  points  price  \
# 0      US                     Martha's Vineyard    96.0  235.0
# 1   Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
#          province     region_1 region_2             variety  \
# 0      California  Napa Valley     Napa  Cabernet Sauvignon
# 1  Northern Spain         Toro      NaN       Tinta de Toro
#
#                     winery last_year_points
# 0                    Heitz               94
# 1  Bodega Carmen Rodríguez               92

# %% [markdown]
# ### Renaming
# The function `rename()`, which lets you change index names and/or column names.

# %%
wine_store.rename(columns={'points': 'score'}).head(2)
# Out:
#   country                           designation  score  price        province  \
# 0      US                     Martha's Vineyard   96.0  235.0      California
# 1   Spain  Carodorum Selección Especial Reserva   96.0  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery  \
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez
#
#   last_year_points
# 0               94
# 1               92

# %% [markdown]
# `rename()` lets you rename index or column values by specifying a `index` or `column` keyword parameter, respectively.
# Here is an example using it to rename some elements of the index.

# %%
wine_store.rename(index={0: 'first', 1: 'second'}).head(2)
# Out:
#        country                           designation  points  price  \
# first       US                     Martha's Vineyard    96.0  235.0
# second   Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
#               province     region_1 region_2             variety  \
# first       California  Napa Valley     Napa  Cabernet Sauvignon
# second  Northern Spain         Toro      NaN       Tinta de Toro
#
#                          winery last_year_points
# first                     Heitz               94
# second  Bodega Carmen Rodríguez               92

# %% [markdown]
# `set_index()` is usually more convenient for rename columns.
#
# Both the row index and the column index can have their `name` attribute.

# %%
wine_store.rename_axis('wines', axis='rows').rename_axis('fields', axis='columns').head(2)
# Out:
# fields country                           designation  points  price  \
# wines
# 0           US                     Martha's Vineyard    96.0  235.0
# 1        Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
# fields        province     region_1 region_2             variety  \
# wines
# 0           California  Napa Valley     Napa  Cabernet Sauvignon
# 1       Northern Spain         Toro      NaN       Tinta de Toro
#
# fields                   winery last_year_points
# wines
# 0                         Heitz               94
# 1       Bodega Carmen Rodríguez               92

# %% [markdown]
# ### Combining
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and\or in non-trivial ways.
# Pandas has three core methods for doing this.
# In order of increasing complexity:
#  - concat()
#  - join()
#  - merge()

# %%
canadian_youtube = pd.read_csv('../data/trending_youtube_video_stat/CAvideos/CAvideos.csv')
british_youtube = pd.read_csv('../data/trending_youtube_video_stat/GBvideos/GBvideos.csv')
russian_youtube = pd.read_csv('../data/trending_youtube_video_stat/RUvideos/RUvideos.csv', encoding='utf_8')

# %% [markdown]
# `concat()` this is usefull when we have data in different DataFrame or Series objects but having the same fields(columns).
#  If we want to study Youtube from multiple countries simultaneously, we can use concat() to smush them together:

# %%
pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %% [markdown]
# The middlemost combiner in terms of complexity is `join()` .
# `join()` lets you combine different DataFrame objects which have an index in common.
#
# For example, to pull down videos that happened to be trending on the same day in both Canada and the UK, we could do the following:

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

# %%
left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
# ...                                                                       ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.02.05       WttN1Z0XF4k
#                                                    18.29.04       WttN1Z0XF4k
#                                                    18.30.04       WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# ...

# %% [markdown]
# The `lsuffix` and `rsuffix` parameters are necessary here because the data has the same column names in both British adn Canadian datasets.
# If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.

# %% [markdown]
# ### Exercise

# %%
wine_store = pd.read_csv('../data/wine_catalog/wine_store_dataset.csv').drop(columns=['Unnamed: 0'])
wine_store.head(2)
# Out:
#   country                           designation  points  price  \
# 0      US                     Martha's Vineyard    96.0  235.0
# 1   Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
#          province     region_1 region_2             variety  \
# 0      California  Napa Valley     Napa  Cabernet Sauvignon
# 1  Northern Spain         Toro      NaN       Tinta de Toro
#
#                     winery last_year_points
# 0                    Heitz               94
# 1  Bodega Carmen Rodríguez               92

# %% [markdown]
# 1) Rename several columns: `region_1` and `region_2` with `region` and `locale`, respectively.

# %%
rename_columns = wine_store.rename(columns={'region_1': 'region', 'region_2': 'locale'})
rename_columns.head(2)
# Out:
#   country                           designation  points  price  \
# 0      US                     Martha's Vineyard    96.0  235.0
# 1   Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
#          province       region locale             variety  \
# 0      California  Napa Valley   Napa  Cabernet Sauvignon
# 1  Northern Spain         Toro    NaN       Tinta de Toro
#
#                     winery last_year_points
# 0                    Heitz               94
# 1  Bodega Carmen Rodríguez               92

# %% [markdown]
# 2) Set the index name in dataset to `wines`.

# %%
index_name = wine_store.rename_axis('wines', axis='columns')
index_name.head(2)
# Out:
# wines country                           designation  points  price  \
# 0          US                     Martha's Vineyard    96.0  235.0
# 1       Spain  Carodorum Selección Especial Reserva    96.0  110.0
#
# wines        province     region_1 region_2             variety  \
# 0          California  Napa Valley     Napa  Cabernet Sauvignon
# 1      Northern Spain         Toro      NaN       Tinta de Toro
#
# wines                   winery last_year_points
# 0                        Heitz               94
# 1      Bodega Carmen Rodríguez               92
