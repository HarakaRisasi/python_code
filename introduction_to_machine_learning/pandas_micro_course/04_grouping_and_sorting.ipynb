# %% [markdown]
# ### Introduction
# Maps allow us to transform data in a DataFrame or Series one value at a time for an entire column. However, often we want to gproup our data,

# %%
import pandas as pd

# %%
wine_store = pd.read_csv('../data/wine_catalog/wine_store_dataset.csv')

# %%
wine_store = wine_store.drop(columns=['Unnamed: 0'])

# %%
wine_store.head()
# Out:
#   country                           designation  points  price  \
# 0      US                     Martha's Vineyard    96.0  235.0
# 1   Spain  Carodorum Selección Especial Reserva    96.0  110.0
# 2      US         Special Selected Late Harvest    96.0   90.0
# 3      US                               Reserve    96.0   65.0
# 4  France                            La Brûlade    95.0   66.0
#
#          province           region_1           region_2             variety  \
# 0      California        Napa Valley               Napa  Cabernet Sauvignon
# 1  Northern Spain               Toro                NaN       Tinta de Toro
# 2      California     Knights Valley             Sonoma     Sauvignon Blanc
# 3          Oregon  Willamette Valley  Willamette Valley          Pinot Noir
# 4        Provence             Bandol                NaN  Provence red blend
#
#                     winery last_year_points
# 0                    Heitz               94
# 1  Bodega Carmen Rodríguez               92
# 2                 Macauley              100
# 3                    Ponzi               94
# 4     Domaine de la Bégude               94

# %% [markdown]
# ### Groupwise analysis
# One function we've been using heavily thus far is the `value_counts()` function.

# %% [markdown]
# The `groupby()` operations involves some combinations of splitting the object, applying a function, and combining the results.
# This can be used to group large amount of data and compute operations on these groups.

# %%
wine_store.groupby('points').points.count() # show us, how many times `points` it appeared.
# Out:
# points
# 80.0       838
# 81.0      1407
# 82.0      3893
# 83.0      5756
# 84.0     10304
# 85.0     11912
# 86.0     14925
# 87.0     19944
# 88.0     17100
# 89.0     12248
# 90.0     15168
# 91.0      9929
# 92.0      8746
# 93.0      5720
# 94.0      3272
# 95.0      1612
# 96.0       655
# 97.0       342
# 98.0       127
# 99.0        43
# 100.0       24
# Name: points, dtype: int64

# %% [markdown]
# `value_counts()` is just a shortcut to this `groupby()` operation.

# %% [markdown]
# For example, to get the expansive wine in each point value category, we can do the following:

# %%
wine_store.groupby('points').price.max()
# Out:
# points
# 80.0       80.0
# 81.0       95.0
# 82.0      150.0
# 83.0      225.0
# 84.0      225.0
# 85.0      320.0
# 86.0      495.0
# 87.0      325.0
# 88.0      325.0
# 89.0      500.0
# 90.0      535.0
# 91.0     2013.0
# 92.0      670.0
# 93.0      770.0
# 94.0     1000.0
# 95.0      850.0
# 96.0     1300.0
# 97.0     1100.0
# 98.0     1900.0
# 99.0     2300.0
# 100.0    1400.0
# Name: price, dtype: float64

# %% [markdown]
# This DataFrame is accessible to us directly using the `apply()` method, and we can manipulate the data in any way we see fit.

# %%
wine_store.groupby('winery').apply(lambda df: df.price.iloc[0])
# Out:
# winery
#  Rondinella          40.0
# '37 Cellars           NaN
# 1+1=3                18.0
# 10 Knots             35.0
# 1000 Stories         19.0
#                      ...
# Ñandú                17.0
# Único Luis Miguel    15.0
# àMaurice             35.0
# áster                26.0
# Štoka                23.0
# Length: 14582, dtype: float64

# %%
wine_store.country.iloc[0]
# Out:
# 'US'

# %%
wine_store.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# x.to_csv('../data/wine_catalog/wine_store_country_winery.csv')
# Out:
#                               country  \
# country   province
# Albania   Mirditë             Albania
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                         designation  points  \
# country   province
# Albania   Mirditë                                               NaN    88.0
# Argentina Mendoza Province                         Nicasia Vineyard    97.0
#           Other                                             Reserva    95.0
# Australia Australia Other                                  Yattarna    92.0
#           New South Wales                        Noble One Botrytis    93.0
# ...                                                             ...     ...
# Uruguay   Juanico                  Preludio Barrel Select Lote N 77    90.0
#           Montevideo        Monte Vide Eu Tannat-Merlot-Tempranillo    90.0
#           Progreso                                              RPF    89.0
#           San Jose                                              NaN    84.0
#           Uruguay                                        Varietales    88.0
#
#                             price          province                 region_1  \
# country   province
# Albania   Mirditë            20.0           Mirditë                      NaN
# Argentina Mendoza Province  120.0  Mendoza Province                  Mendoza
#           Other              90.0             Other                    Salta
# Australia Australia Other    65.0   Australia Other  South Eastern Australia
#           New South Wales    32.0   New South Wales          New South Wales
# ...                           ...               ...                      ...
# Uruguay   Juanico            45.0           Juanico                      NaN
#           Montevideo         57.0        Montevideo                      NaN
#           Progreso           23.0          Progreso                      NaN
#           San Jose           19.0          San Jose                      NaN
#           Uruguay            20.0           Uruguay                      NaN
#
#                            region_2       variety                winery  \
# country   province
# Albania   Mirditë               NaN       Kallmet                Arbëri
# Argentina Mendoza Province      NaN        Malbec  Bodega Catena Zapata
#           Other                 NaN        Malbec                Colomé
# Australia Australia Other       NaN    Chardonnay              Penfolds
#           New South Wales       NaN      Sémillon            De Bortoli
# ...                             ...           ...                   ...
# Uruguay   Juanico               NaN     Red Blend        Familia Deicas
#           Montevideo            NaN     Red Blend                 Bouza
#           Progreso              NaN        Tannat                Pisano
#           San Jose              NaN  Tannat-Syrah              Tanterra
#           Uruguay               NaN        Tannat                Garzón
#
#                            last_year_points
# country   province
# Albania   Mirditë                        82
# Argentina Mendoza Province               92
#           Other                          92
# Australia Australia Other                93
#           New South Wales                98
# ...                                     ...
# Uruguay   Juanico                       100
#           Montevideo                    100
#           Progreso                       81
#           San Jose                       93
#           Uruguay                        98
#
# [451 rows x 10 columns]

# %% [markdown]
# `agg()` lets you run a bunch of different functions on your DataFrame simultaneously.

# %%
wine_store.groupby(['country']).price.agg([len, min, max]).head()
# Out:
#                            len   min    max
# country
# Albania                    2.0  20.0   20.0
# Argentina               4978.0   4.0  250.0
# Australia               4495.0   5.0  850.0
# Austria                 2933.0   8.0  208.0
# Bosnia and Herzegovina     4.0  12.0   13.0

# %% [markdown]
# The `groupby()` will allow you to do lots of really powerfull things with your dataset.

# %% [markdown]
# ### Multi-indexes

# %% [markdown]
# In all of the examples we've seen thus far we've been working with DataFrame of Series objects with a single-label index.
# `groupby()` is slightly different in the fact that, depending on the operation we run we run, it will sometimes result in what is called a `multi-index`.

# %% [markdown]
# A `multi-index` differs from a regular index in that it has multiple levels.

# %%
countries_reviews = wine_store.groupby(['country', 'province']).points.agg([sum, max]) # sum of all price by province and country
countries_reviews
# Out:
#                                  sum   max
# country   province
# Albania   Mirditë              176.0  88.0
# Argentina Mendoza Province  359396.0  97.0
#           Other              68293.0  95.0
# Australia Australia Other    43093.0  92.0
#           New South Wales    18523.0  93.0
# ...                              ...   ...
# Uruguay   Juanico             1355.0  90.0
#           Montevideo           268.0  90.0
#           Progreso             441.0  89.0
#           San Jose             746.0  84.0
#           Uruguay             1254.0  88.0
#
# [451 rows x 2 columns]

# %% [markdown]
# Multi-indeces have several methods for dealing with their tiered structure which are absent for single-level indices.
#
# However, in general the multi-index method you will use most often is the one for converting back to a regular index, the `reset_index()` method:

# %%
countries_reviews.reset_index()
# Out:
#        country          province       sum   max
# 0      Albania           Mirditë     176.0  88.0
# 1    Argentina  Mendoza Province  359396.0  97.0
# 2    Argentina             Other   68293.0  95.0
# 3    Australia   Australia Other   43093.0  92.0
# 4    Australia   New South Wales   18523.0  93.0
# ..         ...               ...       ...   ...
# 446    Uruguay           Juanico    1355.0  90.0
# 447    Uruguay        Montevideo     268.0  90.0
# 448    Uruguay          Progreso     441.0  89.0
# 449    Uruguay          San Jose     746.0  84.0
# 450    Uruguay           Uruguay    1254.0  88.0
#
# [451 rows x 4 columns]

# %% [markdown]
# ### Sorting

# %%
countries_reviews = countries_reviews.reset_index()
countries_reviews.sort_values(by='len')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-c17843d294cb> in <module>
#       1 countries_reviews = countries_reviews.reset_index()
# ----> 2 countries_reviews.sort_values(by='len')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'len'
