# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# path to the file to read
spotify_filepath = "./data/spotify.csv"

# read the file into a variable spotify_data
spotify_data = pd.read_csv(spotify_filepath)

# %%
# get the name of first column
spotify_data.index.names = ['id']

# delete the column with name 'Unnamed: 0'
spotify_data = spotify_data.drop(columns='Unnamed: 0')
spotify_data.to_csv('./data/spotify_clear.csv')

# %%
spotify_data.head()
# Out:
#                      song_name song_popularity song_duration_ms  \
# id
# 0   Boulevard of Broken Dreams              73           262333
# 1                   In The End              66           216933
# 2            Seven Nation Army              76           231733
# 3                   By The Way              74           216933
# 4            How You Remind Me              56           223826
#
#               acousticness danceability              energy instrumentalness  \
# id
# 0   0.005520000000000001kg   0.496mol/L               0.682         2.94e-05
# 1                 0.0103kg   0.542mol/L               0.853              0.0
# 2                0.00817kg   0.737mol/L               0.463            0.447
# 3                 0.0264kg   0.451mol/L                0.97          0.00355
# 4               0.000954kg   0.447mol/L  0.7659999999999999              0.0
#
#      key liveness             loudness audio_mode speechiness    tempo  \
# id
# ...

# %%
# print the last five rows of the data
spotify_data.tail()
# Out:
#                     song_name song_popularity song_duration_ms acousticness  \
# id
# 18830          Let It Breathe              60           159645      0.893kg
# 18831                 Answers              60           205666      0.765kg
# 18832  Sudden Love (Acoustic)              23           182211      0.847kg
# 18833       Gentle on My Mind              55           352280      0.945kg
# 18834                Up to Me              60           193533      0.911kg
#
#                   danceability energy instrumentalness   key liveness  \
# id
# 18830                 0.5mol/L  0.151         6.54e-05  11.0    0.111
# 18831               0.495mol/L  0.161         1.33e-06  11.0    0.105
# 18832  0.7190000000000001mol/L  0.325              0.0   0.0    0.125
# 18833               0.488mol/L  0.326           0.0157   3.0    0.119
# 18834                0.64mol/L  0.381         0.000254   4.0    0.104
#
#       loudness audio_mode speechiness    tempo time_signature  audio_valence
# ...
