# %%
import mysql.connector

mydb = mysql.connector.connect(
    user='root',
    passwd='root',
    host='localhost',
    database='learning_sql_database'
)

print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x00000172FDB51A00>

# %%
mycursor = mydb.cursor()

name = 'Cars' # it doesn't work.
year = 2006

sql = f"""
SELECT Title, Director
FROM sql_lesson_1_movies
WHERE Year BETWEEN 2000 AND 2010
"""

# %%
import pandas as pd

sql = f"""
SELECT Title, Director
FROM sql_lesson_1_movies
WHERE year BETWEEN 2000 AND 2010
"""

pd.read_sql_query(sql,mydb)
# Out:
#              Title        Director
# 0     Finding Nemo  Andrew Stanton
# 1   Monsters, Inc.     Pete Docter
# 2               Up     Pete Docter
# 3      Ratatouille       Brad Bird
# 4      Toy Story 3     Lee Unkrich
# 5             Cars   John Lasseter
# 6  The Incredibles       Brad Bird
# 7           WALL-E  Andrew Stanton

# %%
sql = f"""
SELECT Title, Director
FROM sql_lesson_1_movies
WHERE id = 6
"""
pd.read_sql_query(sql,mydb)
# Out:
#                  Title     Director
# 0  Monsters University  Dan Scanlon

# %%
sql = f"""
SELECT Title, Director
FROM sql_lesson_1_movies
WHERE year BETWEEN 2000 AND 2010
"""
pd.read_sql_query(sql,mydb)
# Out:
#              Title        Director
# 0     Finding Nemo  Andrew Stanton
# 1   Monsters, Inc.     Pete Docter
# 2               Up     Pete Docter
# 3      Ratatouille       Brad Bird
# 4      Toy Story 3     Lee Unkrich
# 5             Cars   John Lasseter
# 6  The Incredibles       Brad Bird
# 7           WALL-E  Andrew Stanton

# %%
sql = f"""
SELECT Title, Director
FROM sql_lesson_1_movies
WHERE year NOT BETWEEN 2000 AND 2010
"""
pd.read_sql_query(sql,mydb)
# Out:
#                  Title        Director
# 0                Brave  Brenda Chapman
# 1               Cars 2   John Lasseter
# 2  Monsters University     Dan Scanlon
# 3          Toy Story 2   John Lasseter
# 4          A Bugs Life   John Lasseter
# 5            Toy Story   John Lasseter

# %%
sql = f"""
SELECT title, director, year
FROM sql_lesson_1_movies
WHERE id BETWEEN 1 AND 5
"""
pd.read_sql_query(sql,mydb)
# Out:
#             title        director  year
# 0    Finding Nemo  Andrew Stanton  2003
# 1           Brave  Brenda Chapman  2012
# 2  Monsters, Inc.     Pete Docter  2001
# 3          Cars 2   John Lasseter  2011
# 4              Up     Pete Docter  2009

# %%
sql = f"""
SELECT title, year
FROM sql_lesson_1_movies
WHERE director = "John Lasseter"
"""
pd.read_sql_query(sql, mydb)
# Out:
#          title  year
# 0       Cars 2  2011
# 1  Toy Story 2  1999
# 2         Cars  2006
# 3  A Bugs Life  1998
# 4    Toy Story  1995

# %%
sql = f"""
SELECT title, year
FROM sql_lesson_1_movies
WHERE director != "John Lasseter"
"""
pd.read_sql_query(sql, mydb)
# Out:
#                  title  year
# 0         Finding Nemo  2003
# 1                Brave  2012
# 2       Monsters, Inc.  2001
# 3                   Up  2009
# 4  Monsters University  2013
# 5          Ratatouille  2007
# 6          Toy Story 3  2010
# 7      The Incredibles  2004
# 8               WALL-E  2008

# %%
sql = f"""
SELECT title, year
FROM sql_lesson_1_movies
WHERE director LIKE "%John Lasseter%"
"""
pd.read_sql_query(sql, mydb)
# Out:
#          title  year
# 0       Cars 2  2011
# 1  Toy Story 2  1999
# 2         Cars  2006
# 3  A Bugs Life  1998
# 4    Toy Story  1995

# %%
sql = f"""
SELECT title, director
FROM sql_lesson_1_movies
WHERE director NOT LIKE "%John Lasseter%"
"""
pd.read_sql_query(sql, mydb)
# Out:
#                  title        director
# 0         Finding Nemo  Andrew Stanton
# 1                Brave  Brenda Chapman
# 2       Monsters, Inc.     Pete Docter
# 3                   Up     Pete Docter
# 4  Monsters University     Dan Scanlon
# 5          Ratatouille       Brad Bird
# 6          Toy Story 3     Lee Unkrich
# 7      The Incredibles       Brad Bird
# 8               WALL-E  Andrew Stanton

# %%
sql = f"""
SELECT title, director
FROM sql_lesson_1_movies
WHERE director LIKE "%asse%"
"""
pd.read_sql_query(sql, mydb)
# Out:
#          title       director
# 0       Cars 2  John Lasseter
# 1  Toy Story 2  John Lasseter
# 2         Cars  John Lasseter
# 3  A Bugs Life  John Lasseter
# 4    Toy Story  John Lasseter
